# %% [markdown]
# ## LLaMA2 chat with SQL
#
# Open source, local LLMs are great to consider for any application that demands data privacy.
#
# SQL is one good example.
#
# This cookbook shows how to perform text-to-SQL using various local versions of LLaMA2 run locally.
#
# ## Packages

# %%
! pip install langchain replicate
! pip install ollama
# Out:
# Requirement already satisfied: langchain in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (0.1.7)
# Requirement already satisfied: replicate in /opt/homebrew/lib/python3.11/site-packages (0.25.2)
# Requirement already satisfied: PyYAML>=5.3 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from langchain) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from langchain) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (0.5.14)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.20 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from langchain) (0.0.20)
# Requirement already satisfied: langchain-core<0.2,>=0.1.22 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from langchain) (0.1.23)
# Requirement already satisfied: langsmith<0.1,>=0.0.83 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from langchain) (0.0.87)
# Requirement already satisfied: numpy<2,>=1 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from langchain) (2.6.1)
# Requirement already satisfied: requests<3,>=2 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: httpx<1,>=0.21.0 in /opt/homebrew/lib/python3.11/site-packages (from replicate) (0.27.0)
# Requirement already satisfied: packaging in /opt/homebrew/lib/python3.11/site-packages (from replicate) (23.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/homebrew/lib/python3.11/site-packages (from replicate) (4.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: anyio in /opt/homebrew/lib/python3.11/site-packages (from httpx<1,>=0.21.0->replicate) (3.7.1)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.11/site-packages (from httpx<1,>=0.21.0->replicate) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from httpx<1,>=0.21.0->replicate) (1.0.3)
# Requirement already satisfied: idna in /opt/homebrew/lib/python3.11/site-packages (from httpx<1,>=0.21.0->replicate) (3.6)
# Requirement already satisfied: sniffio in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from httpx<1,>=0.21.0->replicate) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.21.0->replicate) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from pydantic<3,>=1->langchain) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# DEPRECATION: celery 5.0.5 has a non-standard dependency specifier pytz>dev. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of celery or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: ollama in /opt/homebrew/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /opt/homebrew/lib/python3.11/site-packages (from ollama) (0.27.0)
# Requirement already satisfied: anyio in /opt/homebrew/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (3.7.1)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.0.3)
# Requirement already satisfied: idna in /opt/homebrew/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (3.6)
# Requirement already satisfied: sniffio in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/adityamullick/Library/Python/3.11/lib/python/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama) (0.14.0)
# DEPRECATION: celery 5.0.5 has a non-standard dependency specifier pytz>dev. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of celery or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
! ollama pull llama2:13b-chat
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠋ pulling manifest
# pulling 2609048d349e...   0% ▕                ▏    0 B/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏    0 B/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏    0 B/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏    0 B/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏    0 B/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏    0 B/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏    0 B/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏    0 B/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏    0 B/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏    0 B/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏    0 B/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏    0 B/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏    0 B/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏    0 B/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 297 KB/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 302 KB/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 313 KB/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 322 KB/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 346 KB/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 518 KB/7.4 GB                  pulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 581 KB/7.4 GB  290 KB/s    7h2mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 624 KB/7.4 GB  290 KB/s    7h2mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 747 KB/7.4 GB  290 KB/s    7h2mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 879 KB/7.4 GB  290 KB/s    7h2mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 909 KB/7.4 GB  290 KB/s    7h2mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 1.3 MB/7.4 GB  290 KB/s    7h2mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 1.7 MB/7.4 GB  290 KB/s    7h2mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 1.9 MB/7.4 GB  290 KB/s    7h2mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 2.1 MB/7.4 GB  290 KB/s    7h2mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 2.6 MB/7.4 GB  290 KB/s    7h2mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 3.0 MB/7.4 GB  290 KB/s    7h2mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 3.4 MB/7.4 GB  1.1 MB/s   1h52mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 4.1 MB/7.4 GB  1.1 MB/s   1h52mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 4.4 MB/7.4 GB  1.1 MB/s   1h52mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 4.9 MB/7.4 GB  1.1 MB/s   1h52mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 5.4 MB/7.4 GB  1.1 MB/s   1h52mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 5.5 MB/7.4 GB  1.1 MB/s   1h52mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 6.1 MB/7.4 GB  1.1 MB/s   1h52mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 6.3 MB/7.4 GB  1.1 MB/s   1h52mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 6.7 MB/7.4 GB  1.1 MB/s   1h52mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 7.8 MB/7.4 GB  1.1 MB/s   1h52mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 8.4 MB/7.4 GB  2.0 MB/s    1h0mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 8.8 MB/7.4 GB  2.0 MB/s    1h0mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 8.9 MB/7.4 GB  2.0 MB/s    1h0mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 9.4 MB/7.4 GB  2.0 MB/s    1h0mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏ 9.7 MB/7.4 GB  2.0 MB/s    1h0mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏  10 MB/7.4 GB  2.0 MB/s    1h0mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏  11 MB/7.4 GB  2.0 MB/s    1h0mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏  11 MB/7.4 GB  2.0 MB/s    1h0mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏  11 MB/7.4 GB  2.0 MB/s    1h0mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏  12 MB/7.4 GB  2.0 MB/s    1h0mpulling manifest
# pulling 2609048d349e...   0% ▕                ▏  12 MB/7.4 GB  2.5 MB/s  49m11spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  13 MB/7.4 GB  2.5 MB/s  49m11spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  13 MB/7.4 GB  2.5 MB/s  49m11spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  14 MB/7.4 GB  2.5 MB/s  49m11spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  14 MB/7.4 GB  2.5 MB/s  49m10spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  14 MB/7.4 GB  2.5 MB/s  49m10spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  15 MB/7.4 GB  2.5 MB/s  49m10spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  15 MB/7.4 GB  2.5 MB/s  49m10spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  15 MB/7.4 GB  2.5 MB/s  49m10spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  15 MB/7.4 GB  2.5 MB/s  49m10spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  15 MB/7.4 GB  2.6 MB/s  46m59spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  16 MB/7.4 GB  2.6 MB/s  46m58spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  16 MB/7.4 GB  2.6 MB/s  46m58spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  17 MB/7.4 GB  2.6 MB/s  46m58spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  17 MB/7.4 GB  2.6 MB/s  46m58spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  17 MB/7.4 GB  2.6 MB/s  46m58spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  18 MB/7.4 GB  2.6 MB/s  46m58spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  19 MB/7.4 GB  2.6 MB/s  46m57spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  19 MB/7.4 GB  2.6 MB/s  46m57spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  19 MB/7.4 GB  2.6 MB/s  46m57spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  19 MB/7.4 GB  2.8 MB/s   43m2spulling manifest
# pulling 2609048d349e...   0% ▕                ▏  20 MB/7.4 GB  2.8 MB/s   43m2spulling manifest
# pulling 2609048d349e...   0% ▕                ▏
ulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 130 MB/7.4 GB  3.1 MB/s  38m45spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 130 MB/7.4 GB  2.9 MB/s  41m35spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 130 MB/7.4 GB  2.9 MB/s  41m35spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 131 MB/7.4 GB  2.9 MB/s  41m35spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 132 MB/7.4 GB  2.9 MB/s  41m34spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 132 MB/7.4 GB  2.9 MB/s  41m34spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 132 MB/7.4 GB  2.9 MB/s  41m34spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 133 MB/7.4 GB  2.9 MB/s  41m34spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 133 MB/7.4 GB  2.9 MB/s  41m34spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 133 MB/7.4 GB  2.9 MB/s  41m34spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 133 MB/7.4 GB  2.9 MB/s  41m34spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 133 MB/7.4 GB  2.9 MB/s  42m14spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 133 MB/7.4 GB  2.9 MB/s  42m14spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 133 MB/7.4 GB  2.9 MB/s  42m14spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 133 MB/7.4 GB  2.9 MB/s  42m14spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 134 MB/7.4 GB  2.9 MB/s  42m14spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 134 MB/7.4 GB  2.9 MB/s  42m14spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 134 MB/7.4 GB  2.9 MB/s  42m14spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 134 MB/7.4 GB  2.9 MB/s  42m14spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 134 MB/7.4 GB  2.9 MB/s  42m14spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 134 MB/7.4 GB  2.9 MB/s  42m14spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 135 MB/7.4 GB  2.5 MB/s   49m3spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 135 MB/7.4 GB  2.5 MB/s   49m3spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 135 MB/7.4 GB  2.5 MB/s   49m3spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 136 MB/7.4 GB  2.5 MB/s   49m3spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 136 MB/7.4 GB  2.5 MB/s   49m3spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 136 MB/7.4 GB  2.5 MB/s   49m3spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 136 MB/7.4 GB  2.5 MB/s   49m3spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 136 MB/7.4 GB  2.5 MB/s   49m3spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 136 MB/7.4 GB  2.5 MB/s   49m3spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 136 MB/7.4 GB  2.5 MB/s   49m3spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 136 MB/7.4 GB  2.4 MB/s  50m35spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 136 MB/7.4 GB  2.4 MB/s  50m35spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 137 MB/7.4 GB  2.4 MB/s  50m35spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 137 MB/7.4 GB  2.4 MB/s  50m35spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 137 MB/7.4 GB  2.4 MB/s  50m35spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 137 MB/7.4 GB  2.4 MB/s  50m34spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 138 MB/7.4 GB  2.4 MB/s  50m34spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 138 MB/7.4 GB  2.4 MB/s  50m34spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 138 MB/7.4 GB  2.4 MB/s  50m34spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 139 MB/7.4 GB  2.4 MB/s  50m34spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 139 MB/7.4 GB  2.4 MB/s  50m34spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 139 MB/7.4 GB  2.3 MB/s  51m37spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 139 MB/7.4 GB  2.3 MB/s  51m37spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 139 MB/7.4 GB  2.3 MB/s  51m37spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 139 MB/7.4 GB  2.3 MB/s  51m37spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 139 MB/7.4 GB  2.3 MB/s  51m37spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 139 MB/7.4 GB  2.3 MB/s  51m36spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 139 MB/7.4 GB  2.3 MB/s  51m36spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 139 MB/7.4 GB  2.3 MB/s  51m36spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 139 MB/7.4 GB  2.3 MB/s  51m36spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 139 MB/7.4 GB  2.3 MB/s  51m36spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 140 MB/7.4 GB  2.0 MB/s  59m53spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 140 MB/7.4 GB  2.0 MB/s  59m53spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 140 MB/7.4 GB  2.0 MB/s  59m53spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 140 MB/7.4 GB  2.0 MB/s  59m53spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 141 MB/7.4 GB  2.0 MB/s  59m53spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 141 MB/7.4 GB  2.0 MB/s  59m53spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 141 MB/7.4 GB  2.0 MB/s  59m53spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 141 MB/7.4 GB  2.0 MB/s  59m53spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 141 MB/7.4 GB  2.0 MB/s  59m52spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 141 MB/7.4 GB  2.0 MB/s  59m52spulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 141 MB/7.4 GB  1.9 MB/s    1h2mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 141 MB/7.4 GB  1.9 MB/s    1h2mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 142 MB/7.4 GB  1.9 MB/s    1h2mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 142 MB/7.4 GB  1.9 MB/s    1h2mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 142 MB/7.4 GB  1.9 MB/s    1h2mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 142 MB/7.4 GB  1.9 MB/s    1h2mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 142 MB/7.4 GB  1.9 MB/s    1h2mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 142 MB/7.4 GB  1.9 MB/s    1h2mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 142 MB/7.4 GB  1.9 MB/s    1h2mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 142 MB/7.4 GB  1.9 MB/s    1h2mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 142 MB/7.4 GB  1.9 MB/s    1h4mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 142 MB/7.4 GB  1.9 MB/s    1h4mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 142 MB/7.4 GB  1.9 MB/s    1h4mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 143 MB/7.4 GB  1.9 MB/s    1h4mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 143 MB/7.4 GB  1.9 MB/s    1h4mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 143 MB/7.4 GB  1.9 MB/s    1h4mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 143 MB/7.4 GB  1.9 MB/s    1h4mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 144 MB/7.4 GB  1.9 MB/s    1h4mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 144 MB/7.4 GB  1.9 MB/s    1h4mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 144 MB/7.4 GB  1.9 MB/s    1h4mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 144 MB/7.4 GB  1.8 MB/s    1h7mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 144 MB/7.4 GB  1.8 MB/s    1h7mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 144 MB/7.4 GB  1.8 MB/s    1h7mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 144 MB/7.4 GB  1.8 MB/s    1h7mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 145 MB/7.4 GB  1.8 MB/s    1h7mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 145 MB/7.4 GB  1.8 MB/s    1h7mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 145 MB/7.4 GB  1.8 MB/s    1h7mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 145 MB/7.4 GB  1.8 MB/s    1h7mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 146 MB/7.4 GB  1.8 MB/s    1h7mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 146 MB/7.4 GB  1.8 MB/s    1h7mpulling manifest
# pulling 2609048d349e...   2% ▕                ▏ 146 MB/7.4 GB  1.8 MB/s    1h7mpulling manifest
# ...
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m40spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m40spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m40spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m40spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m40spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m40spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m40spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m40spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m42spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m42spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m42spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m42spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m42spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m42spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m42spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m41spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m41spulling manifest
# pulling 2609048d349e...  93% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m41spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.2 MB/s   3m41spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m29spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m29spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m29spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m29spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m29spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m29spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m29spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m29spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m29spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m29spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m55spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m55spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m55spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m55spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m55spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m55spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m55spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m55spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m55spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m55spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  1.9 MB/s   4m12spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  1.9 MB/s   4m12spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  1.9 MB/s   4m12spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  1.9 MB/s   4m12spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  1.9 MB/s   4m12spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  1.9 MB/s   4m12spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  1.9 MB/s   4m12spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  1.9 MB/s   4m11spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  1.9 MB/s   4m11spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  1.9 MB/s   4m11spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m55spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m55spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m55spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m55spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m54spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m54spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m54spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m54spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m54spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m54spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m44spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m44spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m44spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m43spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m43spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m43spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m43spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m43spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m43spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m43spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m43spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m41spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m41spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m41spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m41spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m41spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m41spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m41spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m41spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m41spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.1 MB/s   3m41spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m58spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m58spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m58spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m57spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m57spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m57spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m57spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m57spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m57spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.0 MB/s   3m56spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m24spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m24spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m24spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m24spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m24spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m24spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m24spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m23spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m23spulling manifest
# pulling 2609048d349e...  94% ▕██████████████  ▏ 6.9 GB/7.4 GB  2.3 MB/s   3m23spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.5 MB/s    3m6spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.5 MB/s    3m6spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.5 MB/s    3m6spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.5 MB/s    3m6spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.5 MB/s    3m6spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.5 MB/s    3m6spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.5 MB/s    3m6spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.5 MB/s    3m5spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.5 MB/s    3m5spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.5 MB/s    3m5spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.4 MB/s    3m8spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.4 MB/s    3m8spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.4 MB/s    3m8spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.4 MB/s    3m7spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.4 MB/s    3m7spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.4 MB/s    3m7spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.4 MB/s    3m7spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.4 MB/s    3m7spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.4 MB/s    3m7spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.4 MB/s    3m7spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.4 MB/s    3m7spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.6 MB/s   2m54spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.6 MB/s   2m53spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.6 MB/s   2m53spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.6 MB/s   2m53spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.6 MB/s   2m53spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.6 MB/s   2m53spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.6 MB/s   2m53spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.6 MB/s   2m52spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.6 MB/s   2m52spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  2.6 MB/s   2m52spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m30spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m29spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m29spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.0 MB/s   2m29spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.2 MB/s   2m20spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.2 MB/s   2m19spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.2 MB/s   2m19spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.2 MB/s   2m19spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.2 MB/s   2m19spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.2 MB/s   2m19spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.2 MB/s   2m19spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.2 MB/s   2m19spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.2 MB/s   2m19spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.2 MB/s   2m19spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.2 MB/s   2m18spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.2 MB/s   2m18spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.2 MB/s   2m18spulling manifest
# pulling 2609048d349e...  94% ▕███████████████ ▏ 6.9 GB/7.4 GB  3.2 MB/s   2m18s

# %% [markdown]
# ## LLM
#
# There are a few ways to access LLaMA2.
#
# To run locally, we use Ollama.ai.
#
# See [here](/docs/integrations/chat/ollama) for details on installation and setup.
#
# Also, see [here](/docs/guides/development/local_llms) for our full guide on local LLMs.
#
# To use an external API, which is not private, we can use Replicate.

# %%
# Local
from langchain_community.chat_models import ChatOllama

llama2_chat = ChatOllama(model="llama2:13b-chat")
llama2_code = ChatOllama(model="codellama:7b-instruct")

# API
from langchain_community.llms import Replicate


# REPLICATE_API_TOKEN = getpass()
# os.environ["REPLICATE_API_TOKEN"] = REPLICATE_API_TOKEN
#replicate_id = "meta/llama-2-13b-chat:f4e2de70d66816a838a89eeeb621910adffb0dd0baba3976c96980970978018d"
# lama2_chat_replicate = Replicate(
#     model=replicate_id, input={"temperature": 0.01, "max_length": 500, "top_p": 1}
# )

# %%
# Simply set the LLM we want to use
llm = llama2_chat
llm
# Out:
# ChatOllama(model='llama2:13b-chat')

# %% [markdown]
# ## DB
#
# Connect to a SQLite DB.
#
# To create this particular DB, you can use the code and follow the steps shown [here](https://github.com/facebookresearch/llama-recipes/blob/main/demo_apps/StructuredLlama.ipynb).

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///nba_roster.db", sample_rows_in_table_info=0)


def get_schema(_):
    return db.get_table_info()


def run_query(query):
    return db.run(query)

# %% [markdown]
# ## Query a SQL Database
#
# Follow the runnables workflow [here](https://python.langchain.com/docs/expression_language/cookbook/sql_db).

# %%
# Prompt
from langchain_core.prompts import ChatPromptTemplate

# Update the template based on the type of SQL Database like MySQL, Microsoft SQL Server and so on
template = """Based on the table schema below, write a SQL query that would answer the user's question:
{schema}

Question: {question}
SQL Query:"""
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "Given an input question, convert it to a SQL query. No pre-amble."),
        ("human", template),
    ]
)

# Chain to query
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

sql_response = (
    RunnablePassthrough.assign(schema=get_schema)
    | prompt
    | llm.bind(stop=["\nSQLResult:"])
    | StrOutputParser()
)

sql_response.invoke({"question": "What team is Klay Thompson on?"})
# Out:
# ---------------------------------------------------------------------------
# OllamaEndpointNotFoundError               Traceback (most recent call last)
# Cell In[17], line 28
#      19 from langchain_core.runnables import RunnablePassthrough
#      21 sql_response = (
#      22     RunnablePassthrough.assign(schema=get_schema)
#      23     | prompt
#      24     | llm.bind(stop=["\nSQLResult:"])
#      25     | StrOutputParser()
#      26 )
# ---> 28 sql_response.invoke({"question": "What team is Klay Thompson on?"})
#
# File ~/Library/Python/3.11/lib/python/site-packages/langchain_core/runnables/base.py:2053, in RunnableSequence.invoke(self, input, config)
#    2051 try:
#    2052     for i, step in enumerate(self.steps):
# -> 2053         input = step.invoke(
#    2054             input,
#    2055             # mark each step as a child run
#    2056             patch_config(
#    2057                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    2058             ),
#    2059         )
#    2060 # finish the root run
#    2061 except BaseException as e:
#
# File ~/Library/Python/3.11/lib/python/site-packages/langchain_core/runnables/base.py:4064, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    4058 def invoke(
#    4059     self,
#    4060     input: Input,
#    4061     config: Optional[RunnableConfig] = None,
#    4062     **kwargs: Optional[Any],
#    4063 ) -> Output:
# -> 4064     return self.bound.invoke(
#    4065         input,
#    4066         self._merge_configs(config),
#    4067         **{**self.kwargs, **kwargs},
#    4068     )
#
# File ~/Library/Python/3.11/lib/python/site-packages/langchain_core/language_models/chat_models.py:166, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     155 def invoke(
#     156     self,
#     157     input: LanguageModelInput,
#    (...)
#     161     **kwargs: Any,
#     162 ) -> BaseMessage:
#     163     config = ensure_config(config)
#     164     return cast(
#     165         ChatGeneration,
# --> 166         self.generate_prompt(
#     167             [self._convert_input(input)],
#     168             stop=stop,
#     169             callbacks=config.get("callbacks"),
#     170             tags=config.get("tags"),
#     171             metadata=config.get("metadata"),
#     172             run_name=config.get("run_name"),
#     173             **kwargs,
#     174         ).generations[0][0],
#     175     ).message
#
# File ~/Library/Python/3.11/lib/python/site-packages/langchain_core/language_models/chat_models.py:544, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     536 def generate_prompt(
#     537     self,
#     538     prompts: List[PromptValue],
#    (...)
#     541     **kwargs: Any,
#     542 ) -> LLMResult:
#     543     prompt_messages = [p.to_messages() for p in prompts]
# --> 544     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Library/Python/3.11/lib/python/site-packages/langchain_core/language_models/chat_models.py:408, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     406         if run_managers:
#     407             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 408         raise e
#     409 flattened_outputs = [
#     410     LLMResult(generations=[res.generations], llm_output=res.llm_output)
#     411     for res in results
#     412 ]
#     413 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/Library/Python/3.11/lib/python/site-packages/langchain_core/language_models/chat_models.py:398, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     395 for i, m in enumerate(messages):
#     396     try:
#     397         results.append(
# --> 398             self._generate_with_cache(
#     399                 m,
#     400                 stop=stop,
#     401                 run_manager=run_managers[i] if run_managers else None,
#     402                 **kwargs,
#     403             )
#     404         )
#     405     except BaseException as e:
#     406         if run_managers:
#
# File ~/Library/Python/3.11/lib/python/site-packages/langchain_core/language_models/chat_models.py:577, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     573     raise ValueError(
#     574         "Asked to cache, but no cache found at `langchain.cache`."
#     575     )
#     576 if new_arg_supported:
# --> 577     return self._generate(
#     578         messages, stop=stop, run_manager=run_manager, **kwargs
#     579     )
#     580 else:
#     581     return self._generate(messages, stop=stop, **kwargs)
#
# File ~/Library/Python/3.11/lib/python/site-packages/langchain_community/chat_models/ollama.py:255, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     231 def _generate(
#     232     self,
#     233     messages: List[BaseMessage],
#    (...)
#     236     **kwargs: Any,
#     237 ) -> ChatResult:
#     238     """Call out to Ollama's generate endpoint.
#     239
#     240     Args:
#    (...)
#     252             ])
#     253     """
# --> 255     final_chunk = self._chat_stream_with_aggregation(
#     256         messages,
#     257         stop=stop,
#     258         run_manager=run_manager,
#     259         verbose=self.verbose,
#     260         **kwargs,
#     261     )
#     262     chat_generation = ChatGeneration(
#     263         message=AIMessage(content=final_chunk.text),
#     264         generation_info=final_chunk.generation_info,
#     265     )
#     266     return ChatResult(generations=[chat_generation])
#
# File ~/Library/Python/3.11/lib/python/site-packages/langchain_community/chat_models/ollama.py:188, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     179 def _chat_stream_with_aggregation(
#     180     self,
#     181     messages: List[BaseMessage],
#    (...)
#     185     **kwargs: Any,
#     186 ) -> ChatGenerationChunk:
#     187     final_chunk: Optional[ChatGenerationChunk] = None
# --> 188     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     189         if stream_resp:
#     190             chunk = _chat_stream_response_to_chat_generation_chunk(stream_resp)
#
# File ~/Library/Python/3.11/lib/python/site-packages/langchain_community/chat_models/ollama.py:161, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     152 def _create_chat_stream(
#     153     self,
#     154     messages: List[BaseMessage],
#     155     stop: Optional[List[str]] = None,
#     156     **kwargs: Any,
#     157 ) -> Iterator[str]:
#     158     payload = {
#     159         "messages": self._convert_messages_to_ollama_messages(messages),
#     160     }
# --> 161     yield from self._create_stream(
#     162         payload=payload, stop=stop, api_url=f"{self.base_url}/api/chat/", **kwargs
#     163     )
#
# File ~/Library/Python/3.11/lib/python/site-packages/langchain_community/llms/ollama.py:233, in _OllamaCommon._create_stream(self, api_url, payload, stop, **kwargs)
#     231 if response.status_code != 200:
#     232     if response.status_code == 404:
# --> 233         raise OllamaEndpointNotFoundError(
#     234             "Ollama call failed with status code 404. "
#     235             "Maybe your model is not found "
#     236             f"and you should pull the model with `ollama pull {self.model}`."
#     237         )
#     238     else:
#     239         optional_detail = response.json().get("error")
#
# OllamaEndpointNotFoundError: Ollama call failed with status code 404. Maybe your model is not found and you should pull the model with `ollama pull llama2:13b-chat`.

# %% [markdown]
# We can review the results:
#
# * [LangSmith trace](https://smith.langchain.com/public/afa56a06-b4e2-469a-a60f-c1746e75e42b/r) LLaMA2-13 Replicate API
# * [LangSmith trace](https://smith.langchain.com/public/2d4ecc72-6b8f-4523-8f0b-ea95c6b54a1d/r) LLaMA2-13 local

# %%
# Chain to answer
template = """Based on the table schema below, question, sql query, and sql response, write a natural language response:
{schema}

Question: {question}
SQL Query: {query}
SQL Response: {response}"""
prompt_response = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "Given an input question and SQL response, convert it to a natural language answer. No pre-amble.",
        ),
        ("human", template),
    ]
)

full_chain = (
    RunnablePassthrough.assign(query=sql_response)
    | RunnablePassthrough.assign(
        schema=get_schema,
        response=lambda x: db.run(x["query"]),
    )
    | prompt_response
    | llm
)

full_chain.invoke({"question": "How many unique teams are there?"})
# Out:
# AIMessage(content=' Based on the table schema and SQL query, there are 30 unique teams in the NBA.')

# %% [markdown]
# We can review the results:
#
# * [LangSmith trace](https://smith.langchain.com/public/10420721-746a-4806-8ecf-d6dc6399d739/r) LLaMA2-13 Replicate API
# * [LangSmith trace](https://smith.langchain.com/public/5265ebab-0a22-4f37-936b-3300f2dfa1c1/r) LLaMA2-13 local

# %% [markdown]
# ## Chat with a SQL DB
#
# Next, we can add memory.

# %%
# Prompt
from langchain.memory import ConversationBufferMemory
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

template = """Given an input question, convert it to a SQL query. No pre-amble. Based on the table schema below, write a SQL query that would answer the user's question:
{schema}
"""
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", template),
        MessagesPlaceholder(variable_name="history"),
        ("human", "{question}"),
    ]
)

memory = ConversationBufferMemory(return_messages=True)

# Chain to query with memory
from langchain_core.runnables import RunnableLambda

sql_chain = (
    RunnablePassthrough.assign(
        schema=get_schema,
        history=RunnableLambda(lambda x: memory.load_memory_variables(x)["history"]),
    )
    | prompt
    | llm.bind(stop=["\nSQLResult:"])
    | StrOutputParser()
)


def save(input_output):
    output = {"output": input_output.pop("output")}
    memory.save_context(input_output, output)
    return output["output"]


sql_response_memory = RunnablePassthrough.assign(output=sql_chain) | save
sql_response_memory.invoke({"question": "What team is Klay Thompson on?"})
# Out:
# ' SELECT "Team" FROM nba_roster WHERE "NAME" = \'Klay Thompson\';'

# %%
# Chain to answer
template = """Based on the table schema below, question, sql query, and sql response, write a natural language response:
{schema}

Question: {question}
SQL Query: {query}
SQL Response: {response}"""
prompt_response = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "Given an input question and SQL response, convert it to a natural language answer. No pre-amble.",
        ),
        ("human", template),
    ]
)

full_chain = (
    RunnablePassthrough.assign(query=sql_response_memory)
    | RunnablePassthrough.assign(
        schema=get_schema,
        response=lambda x: db.run(x["query"]),
    )
    | prompt_response
    | llm
)

full_chain.invoke({"question": "What is his salary?"})
# Out:
# AIMessage(content=' Sure! Here\'s the natural language response based on the given input:\n\n"Klay Thompson\'s salary is $43,219,440."')

# %% [markdown]
# Here is the [trace](https://smith.langchain.com/public/54794d18-2337-4ce2-8b9f-3d8a2df89e51/r).
